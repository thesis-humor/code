# %%
library(readxl)

# %%
library(repr)
options(repr.plot.width=10, repr.plot.height=9)

# %%
TedTalks <- read_excel("Komplett Dataset.xlsx")

# %% [markdown]
# # Descriptive Data

# %% [markdown]
# ## Scatter Plot Matrix

# %%
# Matrix with histogram, correlation and scatter plot with fitted line
# Each significance level is associated to a symbol: p-values(0, 0.001, 0.01, 0.05, 0.1, 1) <=> symbols(“***”, “**”, “*”, “.”, " “)

library("PerformanceAnalytics")
four_ratings_data <- TedTalks[, c(71,73,74,81)]

# print the first 3 rows
head(four_ratings_data, 3)

chart.Correlation(four_ratings_data, histogram=TRUE, pch=190)
# Out:
#   rating_inspiring_percent rating_ingenious_percent rating_unconvincing_percent
# 1 0.05088903               0.158185162              0.03310852
# 2 0.05628518               0.033771107              0.12195122
# 3 0.05494505               0.004709576              0.08320251
#   rating_obnoxious_percent
# 1 0.01961987
# 2 0.02251407
# 3 0.05808477
# Plot with title “”

# %%
# Export to PDF
# rplot = name of pdf

pdf("Scatter_Plot.pdf", bg='transparent', fillOddEven=TRUE)

#Instert graph code here
chart.Correlation(four_ratings_data, histogram=TRUE, pch=190)

dev.off()
# Out:
# pdf
#   2
